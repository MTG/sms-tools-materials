# %% [markdown]
# # Exercise 10-1 — Music piece combining sound transformations
#
# The goal of this exercise is to build a short original music piece (about 1 minute) using the analysis and transformation techniques from the course. Compared with Exercise 8, this assignment has far fewer constraints and is focused on creative design choices.
#
# In E8, your workflow was constrained in several ways. In this exercise you can go beyond those limits:
# 1. You are not restricted to a single analysis model — you may use any model covered in class (STFT, Sinusoidal, SPR, HPR, SPS, HPS), including combinations.
# 2. You are not limited to one transformation per sound — you may chain multiple transformations on the same source.
# 3. You are not required to process a whole sound uniformly — you may segment a sound and apply different models/transformations to each section.
# 4. You are not limited to a single transformation pass — you may use iterative or multi-stage processing when it improves the result.
#
# You are free to combine sounds, models, and transformation strategies to produce a coherent musical piece. If needed, you may modify provided code or write your own helper functions.

# %% [markdown]
# ## Part 1 – Source selection and baseline analysis
#
# Choose several source sounds from Freesound with strong potential for meaningful analysis and creative transformation. Prefer naturally produced sounds (acoustic instruments, speech, nature, ambience); heavily processed sounds are allowed only if you justify their use.
#
# - Select and load your source sounds.
# - For each sound, run an appropriate analysis model and verify that analysis/synthesis **without transformations** is acceptable.
# - Keep notes of model choices and baseline quality checks.
#
# Your baseline resynthesis quality should be good enough that later transformation artefacts are attributable to creative processing decisions, not poor initial analysis.

# %%
import sys, os
from smstools import utilFunctions as UF

# 10-1.1: load source sounds and run baseline analysis/synthesis without transformations
### your code here

# %% [markdown]
# **10-1.2: Conceptual questions on source selection and baseline analysis (answer here)**
#
# 1. List all source sounds (with Freesound links) and justify why each one is a good candidate for transformation in terms of timbre, dynamics, and structure.
# 2. Which analysis model did you choose for each sound (STFT, Sinusoidal, SPR, HPR, SPS, HPS), and why is that model appropriate for that source?
# 3. How did you evaluate baseline analysis/synthesis quality before applying transformations? Describe at least two objective checks (e.g., residual quality, track continuity, spectrogram consistency) and one listening-based check.
# 4. For one source sound, explain a model you tried and rejected. What artefact or limitation did you observe, and why did you switch models or parameters?
# 5. Which source is likely to be the most transformation-friendly, and which is the most fragile? Explain your prediction before building the final mix.

# %% [markdown]
# ## Part 2 – Transform each source sound
#
# Apply different transformations to each selected sound (or to specific sections of each sound). You may use one or more models from class (STFT, Sinusoidal, SPR, HPR, SPS, HPS), and you may chain transformations when justified.
#
# **Task (10-1.3, programming):**
# - Design and execute transformations for each source.
# - Export transformed stems for final composition.
# - Ensure each transformed stem has a clear creative role (texture, rhythm, foreground, transition, etc.).
#
# The result of this part should be a set of transformed materials ready for assembly into a final one-minute piece.

# %%
# 10-1.3: perform transformations for each source sound (or selected sections)
### your code here

# %% [markdown]
# **10-1.4: Conceptual questions on transformation design (answer here)**
#
# 1. For each source sound, list the transformation chain in order (including model, key parameters, and whether processing was whole-sound or section-based).
# 2. What was the creative role of each transformed stem in your composition (e.g., rhythmic layer, bass texture, lead element, transition effect, ambience)?
# 3. Identify one transformation that failed or produced strong artefacts. What caused the issue (analysis mismatch, parameter extremes, model limitation), and how did you fix or replace it?
# 4. Where did you use single-pass vs. multi-pass processing? Explain why multi-pass processing was beneficial (or unnecessary) for at least one stem.
# 5. Choose one stem and explain how changing one parameter by ±20% would alter the perceptual result (pitch identity, roughness, brightness, temporal clarity, or spatial impression).

# %% [markdown]
# ## Part 3 – Arrange, mix, and document the piece
#
# Mix the transformed sounds into a single final composition (overlaps and repetitions are allowed). Use Audacity or any equivalent DAW/editor.
#
# Provide a clear production script describing:
# - Freesound links for all source sounds.
# - The analysis model(s) and transformation strategy used for each source.
# - How stems were arranged and mixed (layering, timing, levels, transitions).
#
# The description should be detailed enough for an evaluator to understand the full workflow and artistic rationale, even if it is not a fully reproducible rendering recipe.

# %%
# 10-1.5: arrange and mix transformed stems into the final piece
### your code here

# %% [markdown]
# **10-1.6: Conceptual questions on arrangement and final mix (answer here)**
#
# 1. Describe the timeline of your final one-minute piece (intro, development, peak, ending) and indicate which stems enter or exit in each section.
# 2. How did you manage overlap and masking between transformed stems? Mention at least two concrete mixing choices (level automation, EQ carving, panning, reverb depth, transient control, or selective muting).
# 3. Pick one moment in the piece where contrast is strongest (e.g., dry/wet, harmonic/noisy, sparse/dense). Which transformations create that contrast, and why is it musically effective?
# 4. If you had to simplify the piece to only two transformed stems while preserving its identity, which two would you keep and why?
# 5. Reflect on the full pipeline: which decision had the biggest impact on final quality — source selection, analysis model choice, transformation chain, or mixing — and what evidence supports your claim?
